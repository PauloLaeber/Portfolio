# %% [markdown]
# # Exemplo de código R para ser integrado ao Portfólio

# %%
df <- read.csv(file = 'data-fictional.csv')
df$currency <- as.numeric(gsub("[^0-9.]", "", df$currency))
df |> head()
# Out:
#   name              phone          address                      postalZip
# 1 Fletcher Combs    1-584-487-3495 363-2705 Ac Ave              JB4M 8YD
# 2 Cynthia Johns     1-616-654-9083 367-618 Sed Avenue           U1 6SD
# 3 Ryder Murray      (535) 334-4198 4059 Justo Rd.               34078
# 4 Shelly Short      1-841-326-2077 P.O. Box 445, 4731 Vitae Ave LV4 7XA
# 5 James Goff        1-353-252-2755 724-9987 Proin St.           W3 7IC
# 6 Frances Carpenter 1-767-854-4841 1345 Mauris, Street          34797
#   region          country        currency
# 1 Gloucestershire United Kingdom 63.84
# 2 Kinross-shire   United Kingdom 68.26
# 3 Delaware        United States  68.47
# 4 Kincardineshire United Kingdom 32.82
# 5 Midlothian      United Kingdom 45.88
# 6 Vermont         United States  95.65

# %%
df |> summary()
# Out:
#         name           phone          address        postalZip
#  Length   :100   Length   :100   Length   :100   Length   :100
#  N.unique :100   N.unique :100   N.unique :100   N.unique :100
#  N.blank  :  0   N.blank  :  0   N.blank  :  0   N.blank  :  0
#  Min.nchar:  9   Min.nchar: 14   Min.nchar: 11   Min.nchar:  5
#  Max.nchar: 17   Max.nchar: 14   Max.nchar: 35   Max.nchar:  8
#
#        region         country       currency
#  Length   :100   Length   :100   Min.   : 0.29
#  N.unique : 60   N.unique :  2   1st Qu.:26.53
#  N.blank  :  0   N.blank  :  0   Median :55.64
#  Min.nchar:  4   Min.nchar: 13   Mean   :52.82
#  Max.nchar: 18   Max.nchar: 14   3rd Qu.:74.44
#                                  Max.   :99.82
